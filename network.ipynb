# %% [markdown]
# Import MNIST

# %%
import mnist_loader

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
test_data = list(test_data)
training_data = list(training_data)
validation_data = list(validation_data)

# %% [markdown]
# Import The Network class we made

# %%
import Network

net = Network.Network([784, 30, 10])

net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0: 1026 / 10000
# Epoch 1: 1023 / 10000
# Epoch 2: 992 / 10000
# Epoch 3: 919 / 10000
# Epoch 4: 887 / 10000
# Epoch 5: 925 / 10000
# Epoch 6: 915 / 10000
# Epoch 7: 852 / 10000
# Epoch 8: 854 / 10000
# Epoch 9: 875 / 10000
# Epoch 10: 852 / 10000
# Epoch 11: 888 / 10000
# Epoch 12: 804 / 10000
# Epoch 13: 791 / 10000
# Epoch 14: 781 / 10000
# Epoch 15: 747 / 10000
# Epoch 16: 753 / 10000
# Epoch 17: 708 / 10000
# Epoch 18: 705 / 10000
# Epoch 19: 674 / 10000
# Epoch 20: 589 / 10000
# Epoch 21: 686 / 10000
# Epoch 22: 655 / 10000
# Epoch 23: 589 / 10000
# Epoch 24: 517 / 10000
# Epoch 25: 492 / 10000
# Epoch 26: 460 / 10000
# Epoch 27: 523 / 10000
# Epoch 28: 514 / 10000
# Epoch 29: 471 / 10000

# %%
import Network

net = Network.Network([784, 100, 10])

net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0: 154 / 10000
# Epoch 1: 142 / 10000
# Epoch 2: 165 / 10000
# Epoch 3: 214 / 10000
# Epoch 4: 185 / 10000
# Epoch 5: 250 / 10000
# Epoch 6: 229 / 10000
# Epoch 7: 217 / 10000
# Epoch 8: 271 / 10000
# Epoch 9: 280 / 10000
# Epoch 10: 260 / 10000
# Epoch 11: 291 / 10000
# Epoch 12: 256 / 10000
# Epoch 13: 260 / 10000
# Epoch 14: 245 / 10000
# Epoch 15: 252 / 10000
# Epoch 16: 299 / 10000
# Epoch 17: 297 / 10000
# Epoch 18: 298 / 10000
# Epoch 19: 327 / 10000
# Epoch 20: 285 / 10000
# Epoch 21: 304 / 10000
# Epoch 22: 306 / 10000
# Epoch 23: 299 / 10000
# Epoch 24: 305 / 10000
# Epoch 25: 328 / 10000
# Epoch 26: 313 / 10000
# Epoch 27: 334 / 10000
# Epoch 28: 314 / 10000
# Epoch 29: 294 / 10000

# %%
import Network

net = Network.Network([784, 100, 10])

net.SGD(training_data, 30, 10, 0.001, test_data=test_data)
# Out:
# Epoch 0: 395 / 10000
# Epoch 1: 399 / 10000
# Epoch 2: 401 / 10000
# Epoch 3: 400 / 10000
# Epoch 4: 398 / 10000
# Epoch 5: 395 / 10000
# Epoch 6: 397 / 10000
# Epoch 7: 398 / 10000
# Epoch 8: 397 / 10000
# Epoch 9: 395 / 10000
# Epoch 10: 395 / 10000
# Epoch 11: 394 / 10000
# Epoch 12: 391 / 10000
# Epoch 13: 392 / 10000
# Epoch 14: 392 / 10000
# Epoch 15: 390 / 10000
# Epoch 16: 389 / 10000
# Epoch 17: 386 / 10000
# Epoch 18: 384 / 10000
# Epoch 19: 382 / 10000
# Epoch 20: 379 / 10000
# Epoch 21: 379 / 10000
# Epoch 22: 377 / 10000
# Epoch 23: 375 / 10000
# Epoch 24: 373 / 10000
# Epoch 25: 372 / 10000
# Epoch 26: 372 / 10000
# Epoch 27: 372 / 10000
# Epoch 28: 371 / 10000
# Epoch 29: 369 / 10000

# %%
import Network

net = Network.Network([784, 30, 10])

net.SGD(training_data, 30, 10, 100.0, test_data=test_data)
# Out:
# Epoch 0: 474 / 10000
# Epoch 1: 474 / 10000
# Epoch 2: 473 / 10000
# Epoch 3: 534 / 10000
# Epoch 4: 534 / 10000
# Epoch 5: 534 / 10000
# Epoch 6: 534 / 10000
# Epoch 7: 534 / 10000
# Epoch 8: 534 / 10000
# Epoch 9: 534 / 10000
# Epoch 10: 534 / 10000
# Epoch 11: 534 / 10000
# Epoch 12: 534 / 10000
# Epoch 13: 534 / 10000
# Epoch 14: 534 / 10000
# Epoch 15: 534 / 10000
# Epoch 16: 534 / 10000
# Epoch 17: 534 / 10000
# Epoch 18: 534 / 10000
# Epoch 19: 534 / 10000
# Epoch 20: 534 / 10000
# Epoch 21: 534 / 10000
# Epoch 22: 534 / 10000
# Epoch 23: 534 / 10000
# Epoch 24: 534 / 10000
# Epoch 25: 534 / 10000
# Epoch 26: 534 / 10000
# Epoch 27: 534 / 10000
# Epoch 28: 534 / 10000
# Epoch 29: 534 / 10000

# %%
import Network

net = Network.Network([784, 100, 10])

net.SGD(training_data, 30, 32, 0.1, test_data=test_data)
# Out:
# Epoch 0: 34 / 10000
# Epoch 1: 29 / 10000
# Epoch 2: 29 / 10000
# Epoch 3: 28 / 10000
# Epoch 4: 25 / 10000
# Epoch 5: 28 / 10000
# Epoch 6: 26 / 10000
# Epoch 7: 26 / 10000
# Epoch 8: 27 / 10000
# Epoch 9: 24 / 10000
# Epoch 10: 25 / 10000
# Epoch 11: 22 / 10000
# Epoch 12: 21 / 10000
# Epoch 13: 19 / 10000
# Epoch 14: 20 / 10000
# Epoch 15: 20 / 10000
# Epoch 16: 21 / 10000
# Epoch 17: 20 / 10000
# Epoch 18: 19 / 10000
# Epoch 19: 19 / 10000
# Epoch 20: 19 / 10000
# Epoch 21: 19 / 10000
# Epoch 22: 20 / 10000
# Epoch 23: 20 / 10000
# Epoch 24: 19 / 10000
# Epoch 25: 19 / 10000
# Epoch 26: 18 / 10000
# Epoch 27: 18 / 10000
# Epoch 28: 18 / 10000
# Epoch 29: 17 / 10000

# %%
sample_image = training_data[0][0]  # First image
predicted_output = net.feedforward(sample_image)

print("Predicted Output:", predicted_output)
print("Expected Output:", training_data[0][1])
# Out:
# Predicted Output: [[1.96775145e-07]
#  [1.00000000e+00]
#  [9.97684939e-01]
#  [9.99736656e-01]
#  [9.08012158e-01]
#  [7.19874773e-02]
#  [9.98788354e-01]
#  [7.41812963e-04]
#  [1.61667470e-05]
#  [7.18818895e-06]
#  [9.99992901e-01]
#  [6.89854290e-01]
#  [9.99109743e-01]
#  [1.06477864e-03]
#  [1.43076499e-05]
#  [4.05843983e-03]
#  [2.43423503e-02]
#  [5.11389121e-01]
#  [7.33125315e-01]
#  [2.12806265e-01]
#  [4.48698223e-03]
#  [6.88592033e-05]
#  [1.90477502e-04]
#  [1.74754340e-03]
#  [9.99999349e-01]
#  [2.57064697e-02]
#  [3.09282251e-07]
#  [9.99999977e-01]
#  [9.90985383e-08]
#  [9.91236671e-01]
#  [2.95731776e-03]
#  [2.03450234e-04]
#  [8.35889965e-01]
#  [9.99963913e-01]
#  [8.02359935e-01]
#  [1.23227835e-03]
#  [2.78259963e-03]
#  [2.45907452e-06]
#  [3.70535281e-05]
#  [9.90872120e-01]
#  [2.42726474e-07]
#  [9.99952475e-01]
#  [9.99772625e-01]
#  [6.74102383e-01]
#  [9.77425305e-01]
#  [9.99691337e-01]
#  [4.27149841e-09]
#  [9.99998998e-01]
#  [3.71676376e-07]
# ...
